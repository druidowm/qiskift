# %%
import qiskit
from Steane import SteaneEncoder,SteaneSyndromeDetector

# %%
e = SteaneEncoder()
circuit = e.getEncoderCircuit(1)
circuit.draw("mpl")

# %%
dag = e.getEncoderDag(3)
dag.draw("mpl")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2170x291 at 0x7F9ECE101ED0>

# %%
circuit.x(3)

# %%
sd = SteaneSyndromeDetector()
circuit = sd.syndromeDetectCircuit(circuit,circuit.qregs)
circuit.draw("mpl")

# %%
from qiskit import Aer,transpile

simulator = Aer.get_backend('qasm_simulator')
circuit = transpile(circuit, simulator)
circuit.draw("mpl")

# %%
result = simulator.run(circuit).result()
plot_histogram(counts, title='Counts')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7faa71203342> in <module>()
# ----> 1 result = simulator.run(circuit).result()
#       2 plot_histogram(counts, title='Counts')
#
# /Users/dugan/anaconda3/envs/qiskit/lib/python3.7/site-packages/qiskit/providers/aer/backends/aerbackend.py in run(self, qobj, backend_options, validate, **run_options)
#     146         # Add backend options to the Job qobj
#     147         qobj = self._format_qobj(
# --> 148             qobj, backend_options=backend_options, **run_options)
#     149
#     150         # Optional validation
#
# /Users/dugan/anaconda3/envs/qiskit/lib/python3.7/site-packages/qiskit/providers/aer/backends/aerbackend.py in _format_qobj(self, qobj, backend_options, **run_options)
#     353         """Return execution sim config dict from backend options."""
# ...

# %%
from qiskit.circuit import QuantumCircuit
from qiskit import Aer,transpile

c = QuantumCircuit(2)
simulator = Aer.get_backend('qasm_simulator')
c = transpile(c, simulator)
result = simulator.run(c).result()
plot_histogram(counts, title='Counts')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-638a6b23a9eb> in <module>()
#       3
#       4 c = QuantumCircuit(2)
# ----> 5 c = transpile(c, simulator)
#       6 result = simulator.run(c).result()
#       7 plot_histogram(counts, title='Counts')
#
# NameError: name 'simulator' is not defined
